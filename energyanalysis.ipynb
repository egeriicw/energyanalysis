# %%
import pandas as pd

# %%
class EnergyAnalysis:
    
    def __init__(self, _ind, _dep, _model):
        self._ind = _ind
        self._dep = _dep
        self._model = _model
    
    def twoP(self):
        _model = "2P"
        pass

    def threePH(self):
        _model = "3PH"
        pass
    
    def threePC(self):
        _model = "3PC"
        pass
    
    def threePCM(self):
        _model = "3PC-M"
        pass
    
    def threePHM(self):
        _model = "3PH-M"
        pass
    
    def threeP(self):
        pass
    
    def fourP(self):
        _model = "4P"
        pass
    
    def fourPM(self):
        _model = "4PM"
        pass
    
    def fiveP(self):
        _model = "5P"
        pass
    
    def fivePM(self):
        _model = "5PM"
        pass
    
    def nonlinear(self):
        pass
    
    def set_independent_values(self, ind):
        pass
    
    def set_dependent_values(self, ped):
        pass
    
    def set_independent_labels(self, labels):
        pass
    
    def set_dependent_labels(self, labels):
        pass
    
    def get_independent_values(self):
        pass
    
    def get_dependent_values(self):
        pass
    
    def get independent_labels(self):
        pass
    
    def get_dependent_labels(self):
        pass
    
    def normalized_annual_consumption(self):
        pass
    
    def sliding_nac(self):
        pass
